# %% [markdown]
# <a href="https://colab.research.google.com/github/VivekYad26/Algorithms-Lab/blob/main/Lab_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Minimum Cost Spanning Tree
# Problem Description:
# A spanning tree of a graph can be defined as a graph with minimal set of edges that connect all vertices. A minimum spanning tree of a graph is a spanning tree of the graph with least weight (where the weight is computed by adding the weights of all the edges in the spanning tree). In general, a graph can have multiple minimum spanning trees. The problem is to find a minimum spanning tree of a graph.

# %% [markdown]
# This implementation uses a dictionary to represent the weighted graph, where the vertices are keys, and the values are dictionaries containing their adjacent vertices and their weights.
#
# Please note that this implementation assumes that the input graph is connected and weighted.
#
# First, let's create a simple graph to demonstrate Prim's algorithm:

# %%
graph = {
    "A": {"B": 10, "C": 15, "D": 20},
    "B": {"A": 10, "C": 12},
    "C": {"A": 15, "B": 12, "D": 18},
    "D": {"A": 20, "C": 18},
}

# %% [markdown]
# Now, let's implement Prim's algorithm:

# %%
def prim_algorithm(graph):
    min_tree = {}
    visited = set()
    min_tree[list(graph.keys())[0]] = []
    min_weight = 0

    while len(visited) < len(graph):
        min_edge = float('inf')
        next_vertex = None
        for vertex in min_tree:
            for adj_vertex, weight in graph[vertex].items():
                if adj_vertex not in visited:
                    if weight < min_edge:
                        min_edge = weight
                        next_vertex = adj_vertex

        min_tree[next_vertex] = []
        visited.add(next_vertex)
        min_weight += min_edge

    return min_tree, min_weight

# %% [markdown]
# Now, let's run the Prim's algorithm on the example graph:
# Keep in mind that this example uses a simple representation of a graph, but for more complex cases, you might want to use a library such as NetworkX to represent and manipulate graphs.

# %%
mst, min_weight = prim_algorithm(graph)
print("Minimum Spanning Tree: ", mst)
print("Minimum Weight: ", min_weight)
# Out:
# Minimum Spanning Tree:  {'A': [], 'B': [], 'C': [], 'D': []}
# Minimum Weight:  50

# %% [markdown]
# Take Differnt example of input graph as discussed in lecture slide and use above code to verify the output

# %%
graph_new = {
    "A": {"B": 4, "H": 8},
    "B": {"A": 4, "C": 8, "H": 11},
    "C": {"B": 8, "D": 7, "F": 4, "I": 2},
    "D": {"C": 7, "E": 9, "F": 14},
    "E": {"D": 9, "F": 10},
    "F": {"C": 4, "D": 14, "E": 10, "G": 2},
    "G": {"F": 2, "H": 1, "I": 6},
    "H": {"A": 8, "B": 11, "G": 1, "I": 7},
    "I": {"C": 2, "G": 6, "H": 7}
}

kruskal_mst, kruskal_min_weight = kruskal_algorithm(graph_new)
print("Minimum Spanning Tree (Kruskal's, New Graph): ", kruskal_mst)
print("Minimum Weight (Kruskal's, New Graph): ", kruskal_min_weight)
# Out:
# Minimum Spanning Tree (Kruskal's, New Graph):  [('G', 'H', 1), ('C', 'I', 2), ('F', 'G', 2), ('A', 'B', 4), ('C', 'F', 4), ('C', 'D', 7), ('A', 'H', 8), ('D', 'E', 9)]
# Minimum Weight (Kruskal's, New Graph):  37

# %%
mst_new, min_weight_new = prim_algorithm(graph_new)
print("Minimum Spanning Tree (New Graph): ", mst_new)
print("Minimum Weight (New Graph): ", min_weight_new)
# Out:
# Minimum Spanning Tree (New Graph):  {'A': [], 'B': [], 'H': [], 'G': [], 'F': [], 'C': [], 'I': [], 'D': [], 'E': []}
# Minimum Weight (New Graph):  41

# %% [markdown]
# Now, let's run Kruskal's algorithm on the `graph_new` example:

# %%
class DisjointSetUnion:
    def __init__(self, vertices):
        self.parent = {v: v for v in vertices}
        self.rank = {v: 0 for v in vertices}

    def find(self, i):
        if self.parent[i] == i:
            return i
        self.parent[i] = self.find(self.parent[i])
        return self.parent[i]

    def union(self, i, j):
        root_i = self.find(i)
        root_j = self.find(j)
        if root_i != root_j:
            if self.rank[root_i] < self.rank[root_j]:
                self.parent[root_i] = root_j
            elif self.rank[root_i] > self.rank[root_j]:
                self.parent[root_j] = root_i
            else:
                self.parent[root_j] = root_i
                self.rank[root_i] += 1
            return True
        return False

def kruskal_algorithm(graph):
    edges = []
    for u in graph:
        for v, weight in graph[u].items():
            if u < v:
                edges.append((weight, u, v))

    edges.sort()

    vertices = list(graph.keys())
    dsu = DisjointSetUnion(vertices)

    min_spanning_tree = []
    min_weight = 0
    num_edges = 0

    while num_edges < len(vertices) - 1 and edges:
        weight, u, v = edges.pop(0)

        if dsu.union(u, v):
            min_spanning_tree.append((u, v, weight))
            min_weight += weight
            num_edges += 1

    if num_edges != len(vertices) - 1:
        return [], 0

    return min_spanning_tree, min_weight
