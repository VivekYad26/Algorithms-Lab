# %% [markdown]
# <a href="https://colab.research.google.com/github/VivekYad26/Algorithms-Lab/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):

    distances = {}
    visited = []

    for node in graph:
        distances[node] = float('inf')

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance

    return distances

# %%
graph = {
'A': {'B': 4, 'C': 2},
'B': {'A': 4, 'C': 5, 'D': 10},
'C': {'A': 2, 'B': 5, 'D': 3},
'D': {'B': 10, 'C': 3}
}

result = dijkstra(graph, 'A')

for node in result:
    print("Distance from A to", node, "=", result[node])
# Out:
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.

# %%
def get_user_graph():
    graph = {}
    print("\n--- Enter Graph Details ---")
    print("Enter nodes and their neighbors with weights. Type 'done' for nodes or neighbors when finished.")

    while True:
        node_name = input("Enter node name (or 'done' to finish adding nodes): ").strip().upper()
        if node_name == 'DONE':
            break
        if not node_name:
            print("Node name cannot be empty. Please try again.")
            continue

        graph[node_name] = {}
        print(f"  Adding neighbors for node '{node_name}':")
        while True:
            neighbor_input = input(f"    Enter neighbor and weight for '{node_name}' (e.g., 'B 5', or 'done' to finish neighbors): ").strip().upper()
            if neighbor_input == 'DONE':
                break
            if not neighbor_input:
                print("Neighbor input cannot be empty. Please try again.")
                continue

            try:
                neighbor, weight_str = neighbor_input.split()
                weight = int(weight_str)
                if weight < 0:
                    print("Weight cannot be negative. Please enter a non-negative integer.")
                    continue
                graph[node_name][neighbor] = weight
            except ValueError:
                print("Invalid input format. Please use 'NODE WEIGHT' (e.g., 'B 5').")
                continue
    return graph

def display_shortest_paths_with_details(distances, predecessors, start_node):
    print(f"\n--- Shortest Paths from Source '{start_node}' ---")
    for target_node in distances:
        if target_node == start_node:
            print(f"Path from {start_node} to {target_node}: {start_node} (Distance: 0)")
            continue

        if distances[target_node] == float('inf'):
            print(f"Path from {start_node} to {target_node}: No path (Distance: Infinity)")
        else:
            path = get_shortest_path(predecessors, start_node, target_node)
            path_str = " -> ".join(path)
            print(f"Path from {start_node} to {target_node}: {path_str} (Distance: {distances[target_node]})\n")
